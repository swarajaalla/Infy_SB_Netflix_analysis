# %%
import pandas as pd
file_path ="/Volumes/workspace/default/netflix/netflix_cleaned.csv"
df = pd.read_csv(file_path)
display(df.head(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Ensure 'date_added' is datetime format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Extract year from 'date_added'
df['added_year'] = df['date_added'].dt.year

# Group by year
content_growth = df['added_year'].value_counts().sort_index()

display(content_growth.head())
# Out:
# added_year
# 2008.0     2
# 2009.0     2
# 2010.0     1
# 2011.0    13
# 2012.0     3
# Name: count, dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.lineplot(x=content_growth.index, y=content_growth.values, marker='o', color='crimson')
plt.title("Netflix Content Growth Over Time", fontsize=14)
plt.xlabel("Year Added")
plt.ylabel("Number of Titles Added")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='type', hue='type', data=df, palette='pastel', legend=False)
plt.title("Distribution of Content Type (Movies vs TV Shows)")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='rating', hue='rating', data=df, 
              order=df['rating'].value_counts().index, 
              palette="coolwarm", legend=False)
plt.title("Distribution of Ratings on Netflix")
plt.xlabel("Count")
plt.ylabel("Rating")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    x='Count', 
    y='Genre', 
    hue='Genre',            # Added hue for color mapping
    data=genre_counts, 
    palette="viridis", 
    legend=False            # Hide redundant legend
)
plt.title("Top 10 Most Common Genres on Netflix")
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    x='Count', 
    y='Country', 
    hue='Country',          # Added hue to enable color mapping
    data=country_counts, 
    palette="cubehelix", 
    legend=False            # Hide duplicate legend
)
plt.title("Top 10 Countries Contributing Netflix Content")
plt.xlabel("Count")
plt.ylabel("Country")
plt.show()

# %%
# Distribution of Release Years
plt.figure(figsize=(10,4))
sns.histplot(df['release_year'], bins=20, kde=True, color='skyblue')
plt.title("Distribution of Release Years")
plt.show()
